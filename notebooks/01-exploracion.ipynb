# %%
# !pip install pandas numpy requests matplotlib seaborn scikit-learn plotly
# Out:
# Requirement already satisfied: pandas in /workspaces/Quintero_Sofia_Fernandez_Maria/.venv/lib/python3.12/site-packages (2.3.3)
# Requirement already satisfied: numpy in /workspaces/Quintero_Sofia_Fernandez_Maria/.venv/lib/python3.12/site-packages (2.3.5)
# Requirement already satisfied: requests in /workspaces/Quintero_Sofia_Fernandez_Maria/.venv/lib/python3.12/site-packages (2.32.5)
# Requirement already satisfied: matplotlib in /workspaces/Quintero_Sofia_Fernandez_Maria/.venv/lib/python3.12/site-packages (3.10.8)
# Requirement already satisfied: seaborn in /workspaces/Quintero_Sofia_Fernandez_Maria/.venv/lib/python3.12/site-packages (0.13.2)
# Requirement already satisfied: scikit-learn in /workspaces/Quintero_Sofia_Fernandez_Maria/.venv/lib/python3.12/site-packages (1.8.0)
# Requirement already satisfied: plotly in /workspaces/Quintero_Sofia_Fernandez_Maria/.venv/lib/python3.12/site-packages (6.5.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /workspaces/Quintero_Sofia_Fernandez_Maria/.venv/lib/python3.12/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /workspaces/Quintero_Sofia_Fernandez_Maria/.venv/lib/python3.12/site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /workspaces/Quintero_Sofia_Fernandez_Maria/.venv/lib/python3.12/site-packages (from pandas) (2025.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in /workspaces/Quintero_Sofia_Fernandez_Maria/.venv/lib/python3.12/site-packages (from requests) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /workspaces/Quintero_Sofia_Fernandez_Maria/.venv/lib/python3.12/site-packages (from requests) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /workspaces/Quintero_Sofia_Fernandez_Maria/.venv/lib/python3.12/site-packages (from requests) (2.6.2)
# Requirement already satisfied: certifi>=2017.4.17 in /workspaces/Quintero_Sofia_Fernandez_Maria/.venv/lib/python3.12/site-packages (from requests) (2025.11.12)
# Requirement already satisfied: contourpy>=1.0.1 in /workspaces/Quintero_Sofia_Fernandez_Maria/.venv/lib/python3.12/site-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /workspaces/Quintero_Sofia_Fernandez_Maria/.venv/lib/python3.12/site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /workspaces/Quintero_Sofia_Fernandez_Maria/.venv/lib/python3.12/site-packages (from matplotlib) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /workspaces/Quintero_Sofia_Fernandez_Maria/.venv/lib/python3.12/site-packages (from matplotlib) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /workspaces/Quintero_Sofia_Fernandez_Maria/.venv/lib/python3.12/site-packages (from matplotlib) (25.0)
# Requirement already satisfied: pillow>=8 in /workspaces/Quintero_Sofia_Fernandez_Maria/.venv/lib/python3.12/site-packages (from matplotlib) (12.0.0)
# Requirement already satisfied: pyparsing>=3 in /workspaces/Quintero_Sofia_Fernandez_Maria/.venv/lib/python3.12/site-packages (from matplotlib) (3.2.5)
# Requirement already satisfied: scipy>=1.10.0 in /workspaces/Quintero_Sofia_Fernandez_Maria/.venv/lib/python3.12/site-packages (from scikit-learn) (1.16.3)
# Requirement already satisfied: joblib>=1.3.0 in /workspaces/Quintero_Sofia_Fernandez_Maria/.venv/lib/python3.12/site-packages (from scikit-learn) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.2.0 in /workspaces/Quintero_Sofia_Fernandez_Maria/.venv/lib/python3.12/site-packages (from scikit-learn) (3.6.0)
# Requirement already satisfied: narwhals>=1.15.1 in /workspaces/Quintero_Sofia_Fernandez_Maria/.venv/lib/python3.12/site-packages (from plotly) (2.14.0)
# Requirement already satisfied: six>=1.5 in /workspaces/Quintero_Sofia_Fernandez_Maria/.venv/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)

# %% [markdown]
# ## 1. Importar Librerias

# %%
import pandas as pd
import numpy as np
import requests

# %% [markdown]
# ## 2. Cargar Datos desde API SODA3 (JSON)

# %%
url = "https://www.datos.gov.co/resource/3t73-n4q9.json"

response = requests.get(url, params={'$limit': 15000})

if response.status_code == 200:
    data = response.json()
    df = pd.DataFrame(data)
    print(f"Datos cargados: {len(df)} registros")
else:
    print(f"Error: {response.status_code}")
# Out:
# Datos cargados: 12534 registros

# %% [markdown]
# ## 3. Primeras Filas

# %%
df.head()
# Out:
#   principio_activo unidad_de_dispensacion              concentracion  \
# 0        Midazolam                Ampolla            Midazolam 15 mg
# 1  Acido Valproico                Tableta  Divalproato Sodico 500 mg
# 2  Acido Valproico                Tableta  Divalproato Sodico 500 mg
# 3       Fluoxetina                Capsula           Fluoxetina 20 mg
# 4   Proximetacaina                 Frasco        Proximetacaina 5 mg
#
#   unidad_base nombre_comercial fabricante precio_por_tableta factoresprecio  \
# 0          ml         Dormicum  Siegfried            11199.8           Alto
# 1          mg          Valcote  Lafrancol        3752.866667          Medio
# 2          mg          Valcote  Lafrancol        1777.266522          Medio
# 3          mg       Fluoxetina     Genfar         329.295281          Medio
# 4          ml          Alcaine      Alcon        64184.74576          Medio
#
#   numerofactor
# 0            3
# 1            2
# 2            2
# 3            2
# 4            2

# %%
df.tail()
# Out:
#         principio_activo unidad_de_dispensacion            concentracion  \
# 12529       Valaciclovir                Tableta      Valaciclovir 500 mg
# 12530         Budesonida                Aerosol        Budesonida 50 mcg
# 12531         Budesonida                Aerosol        Budesonida 50 mcg
# 12532       Metocarbamol                Tableta      Metocarbamol 750 mg
# 12533  Hidroclorotiazida                Tableta  Hidroclorotiazida 25 mg
#
#       unidad_base   nombre_comercial       fabricante precio_por_tableta  \
# 12529          mg            Valtrex  Glaxosmithkline        12630.64593
# 12530       dosis             B-Cort       Grunenthal        145251.4555
# 12531       dosis             B-Cort       Grunenthal        17483.53528
# 12532          mg       Metocarbamol          Memphis        473.1286377
# 12533          mg  Hidroclorotiazida          Memphis        108.1126941
#
#       factoresprecio numerofactor
# 12529           Alto            3
# 12530          Medio            2
# 12531          Medio            2
# 12532          Medio            2
# 12533          Medio            2

# %% [markdown]
# ## 4. Dimensiones

# %%
print(f"Filas: {df.shape[0]}")
print(f"Columnas: {df.shape[1]}")
# Out:
# Filas: 12534
# Columnas: 9

# %% [markdown]
# ## 5. Informacion General

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12534 entries, 0 to 12533
# Data columns (total 9 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   principio_activo        12534 non-null  object
#  1   unidad_de_dispensacion  12534 non-null  object
#  2   concentracion           12534 non-null  object
#  3   unidad_base             12534 non-null  object
#  4   nombre_comercial        12534 non-null  object
#  5   fabricante              12534 non-null  object
#  6   precio_por_tableta      12534 non-null  object
#  7   factoresprecio          12534 non-null  object
#  8   numerofactor            12534 non-null  object
# dtypes: object(9)
# memory usage: 881.4+ KB

# %% [markdown]
# ## 6. Estadisticas Descriptivas

# %%
df.describe()
# Out:
#        principio_activo unidad_de_dispensacion    concentracion unidad_base  \
# count             12534                  12534            12534       12534
# unique             1753                     33             3526          21
# top        Acetaminofen                Tableta  Clotrimazol 1 g          mg
# freq                133                   4984               52        6588
#
#        nombre_comercial     fabricante precio_por_tableta factoresprecio  \
# count             12534          12534              12534          12534
# unique             4787            454              11759              3
# top        Betametasona  Tecnoquimicas              15000          Medio
# freq                 39            580                 12           7086
#
#        numerofactor
# count         12534
# unique            3
# top               2
# freq           7086

# %% [markdown]
# ## 7. Valores Nulos

# %%
nulos = df.isnull().sum()
print(nulos[nulos > 0])
# Out:
# Series([], dtype: int64)

# %% [markdown]
# ## 8. Valores Unicos

# %%
for col in df.columns:
    print(f"{col}: {df[col].nunique()} valores unicos")
# Out:
# principio_activo: 1753 valores unicos
# unidad_de_dispensacion: 33 valores unicos
# concentracion: 3526 valores unicos
# unidad_base: 21 valores unicos
# nombre_comercial: 4787 valores unicos
# fabricante: 454 valores unicos
# precio_por_tableta: 11759 valores unicos
# factoresprecio: 3 valores unicos
# numerofactor: 3 valores unicos

# %% [markdown]
# ## 9. Top Principios Activos

# %%
if 'principio_activo' in df.columns:
    print(df['principio_activo'].value_counts().head(10))
# Out:
# principio_activo
# Acetaminofen        133
# Ibuprofeno          100
# Rosuvastatina        95
# Nitazoxanida         95
# Diclofenaco          94
# Clotrimazol          87
# Atorvastatina        85
# Betametasona         83
# Cloruro De Sodio     79
# Meloxicam            79
# Name: count, dtype: int64

# %% [markdown]
# ## 10. Top Fabricantes

# %%
if 'fabricante' in df.columns:
    print(df['fabricante'].value_counts().head(10))

    #Cantidad de fabricantes
    print(f"Cantidad de fabricantes: {df['fabricante'].nunique()}")
# Out:
# fabricante
# Tecnoquimicas    580
# Procaps          408
# Mega Labs        348
# Lafrancol        336
# Genfar           296
# Novamed          279
# Siegfried        276
# Pfizer           244
# Bioquifar        219
# La Sante         216
# Name: count, dtype: int64
# Cantidad de fabricantes: 454

# %% [markdown]
# ## 11. Analisis de Precios

# %%
if 'precio_por_tableta' in df.columns:
    df['precio_por_tableta'] = pd.to_numeric(df['precio_por_tableta'], errors='coerce')
    
    print(f"Precio minimo: ${df['precio_por_tableta'].min():.2f}")
    print(f"Precio maximo: ${df['precio_por_tableta'].max():.2f}")
    print(f"Precio promedio: ${df['precio_por_tableta'].mean():.2f}")
    print(f"Precio mediano: ${df['precio_por_tableta'].median():.2f}")
# Out:
# Precio minimo: $0.09
# Precio maximo: $257103178.00
# Precio promedio: $155408.34
# Precio mediano: $3891.22

# %% [markdown]
# ## 12. Guardar Datos Crudos

# %%
df.to_csv('../data/raw/medicamentos_raw.csv', index=False, encoding='utf-8-sig')
